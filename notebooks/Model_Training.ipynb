# %% [markdown]
# # Model Training
# Executes cross-validated training, MLflow tracking, diagnostics, model registration, and joblib persistence.

# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parent))
from src.train import train
summary = train('../config.yaml')
summary
