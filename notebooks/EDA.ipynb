# %% [markdown]
# # Heart Disease EDA
# This notebook runs the reusable production EDA module and saves all figures in `../screenshots/`.

# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parent))
from src.preprocess import load_dataset
from src.evaluate import create_eda_plots
data = load_dataset('../data/heart_disease.csv')
display(data.head())
display(data.describe(include='all'))
display(data.isna().sum().to_frame('missing_values'))
create_eda_plots(data, '../screenshots')
